# %% [markdown]
# 经典的线性判别分析已经经历了巨大的发展，并且最近已经扩展到不同的案例中。在本文中，我们提出了一种名为稀疏张量判别分析（STDA）的新颖判别子空间学习方法，该方法进一步将最近提出的多线性判别分析扩展到稀疏情况。
#
# - 通过将L1和L2范数引入STDA的目标函数，我们可以获得多个相互关联的稀疏判别子空间用于特征提取。
#
# 由于没有封闭形式的解决方案，
#
# - k模式优化技术和L1范数稀疏回归结合
#
# 起来，迭代学习沿着张量的不同模式的最优稀疏判别子空间。此外，每个子空间中的每个非零元素都是从最重要的变量/因素中选取的，因此STDA具有比其他判别子空间方法更好的性能潜力。在面部数据库（Yale，FERET和CMU PIE面部数据库）和Weizmann动作数据库上的广泛实验表明，所提出的STDA算法显示出与比较的基于张量的方法相比最具竞争力的性能，尤其是在小样本大小情况下。
